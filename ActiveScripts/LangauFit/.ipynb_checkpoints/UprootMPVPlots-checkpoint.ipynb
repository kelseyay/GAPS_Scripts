# %%
#This code aims to import, into python, the landau-fitted histogram produced by LRMSFullEdep.C / TheChoseOne.C and similar codes
import uproot
import numpy as np
import matplotlib.pyplot as plt

hhist = uproot.open("p4hLGFit.root") #Saved root histogram pre-fitted in the root macro
h = uproot.open("p4hLGFit.root:h0_l0r5m3s17") #Pull the fit function separately
simhist = uproot.open("212hLGFit.root")
sim = uproot.open("212hLGFit.root:h0_l0r5m3s17") #Pull the fit function separately

hist_mcm = hhist["h0_l0r5m3s17"] #This variable involves the actual histogram, not the fit
edges = hist_mcm.axis().edges()  # Using h1's binning
values1 = hist_mcm.values()

hist_sim = simhist["h0_l0r5m3s17"] #This variable involves the actual histogram, not the fit
simedges = hist_sim.axis().edges()  # Using h1's binning
values2 = hist_sim.values()

f = h.member("fFunctions")[0]
fsim = sim.member("fFunctions")[0]

#Need to save the x and y values of the fit
l = list(f.member("fSave"))                                 
x_values = np.linspace(l[-2], l[-1], len(l[:-2]))
y_values = l[:-2]

#Need to save the x and y values of the fit
lsim = list(fsim.member("fSave"))
xsim_values = np.linspace(lsim[-2], lsim[-1], len(lsim[:-2]))
ysim_values = lsim[:-2]

# Create the plot
plt.figure(figsize=(8, 8))

plt.hist(edges[:-1], bins=edges, histtype='step', hatch='////////', weights=values1, alpha=0.65, label=hist_mcm.name,color='mediumblue')
plt.plot(x_values, y_values, color="mediumblue", linewidth = 3) #Plot the fit
plt.hist(simedges[:-1], bins=simedges, histtype='step', hatch = '\\\\\\\\\\\\\\', weights=values2, alpha=0.55, label=hist_sim.name,color='tomato')
plt.plot(xsim_values, ysim_values, color="tomato",linestyle='--',linewidth = 3) #Plot the fit

plt.xlabel("Energy Deposition of Hit $\\times$ Cos($\\theta$) [MeV]", fontsize = 18)
plt.ylabel("Number of Hits on Track", fontsize = 18)
plt.tick_params(axis='both', labelsize=12)
plt.title('')
#plt.grid(True, alpha=0.3) #Make grid with opacity 0.3

mcmmpvvals = str(round(list(f.member("fFormula").member("fClingParameters"))[1], 2)) + " $\pm$ " + str(round(list(f.member("fFormula").member("fClingParameters"))[2], 2)) + " MeV"
simmpvvals = str(round(list(fsim.member("fFormula").member("fClingParameters"))[1], 2)) + " $\pm$ " + str(round(list(fsim.member("fFormula").member("fClingParameters"))[2], 2)) + " MeV"

plt.xlabel("Energy deposition of hit $\\times$ cos($\\theta$) [MeV]", fontsize = 18)
plt.ylabel("Number of hits on track", fontsize = 18)
plt.title('')

plt.xlim(0.3, 3.5)
plt.ylim(0.1, 200)
plt.yscale('log')
plt.minorticks_off()

#Axis formatting
ax = plt.gca()
ax.tick_params(axis='both', which='major', direction='in', labelsize=16, width=1.5, length=6, top=True, right=True, labeltop=False, labelright=False)

plt.legend(['McMurdo Data: 12-13-2024', 'MPV: ' + mcmmpvvals, 'Muon MC', 'MPV: ' + simmpvvals], fontsize = 18,frameon=False)


# adding 'PRELIMINARY' watermark right below the legend (currently in top left corner)
ax.text(0.8, 0.7, 'PRELIMINARY', verticalalignment='bottom', horizontalalignment='right', transform=ax.transAxes, color='gray', fontsize=16)

plt.xlim(0.3, 3.5)
plt.ylim(0.1, 200)
plt.tight_layout()
plt.savefig('MCM_and_Sim_MPV.png')
plt.show()


plt.figure(figsize=(8, 8))

plt.hist(edges[:-1], bins=edges,histtype='step', hatch='////////', weights=values1, alpha=0.5, label=hist_mcm.name,color='mediumblue')
plt.plot(x_values, y_values, color="mediumblue",linewidth = 3) #Plot the fit

plt.xlabel("Energy deposition of hit $\\times$ cos($\\theta$) [MeV]", fontsize = 18)
plt.ylabel("Number of hits on track", fontsize = 18)
plt.title('')
plt.xlim(0.3, 3.5)
plt.ylim(0.1, 200)
plt.yscale('log')
plt.minorticks_off()

#Axis formatting
ax = plt.gca()
ax.tick_params(axis='both', which='major', direction='in', labelsize=16, width=1.5, length=6, top=True, right=True, labeltop=False, labelright=False)


# adding 'PRELIMINARY' watermark right below the legend (currently in top left corner)
ax.text(0.8, 0.8, 'PRELIMINARY', verticalalignment='bottom', horizontalalignment='right', transform=ax.transAxes, color='gray', fontsize=16)

plt.legend(['McMurdo Data: 12-13-2024', 'MPV: ' + mcmmpvvals], fontsize = 18,frameon=False)
plt.tight_layout()
plt.savefig('MCM_MPV.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 46
#      43 plt.title('')
#      44 #plt.grid(True, alpha=0.3) #Make grid with opacity 0.3
# ---> 46 mcmmpvvals = str(round(list(f.member("fFormula").member("fClingParameters"))[1], 2)) + " $\pm$ " + str(round(list(f.member("fFormula").member("fClingParameters"))[2], 2)) + " MeV"
#      47 simmpvvals = str(round(list(fsim.member("fFormula").member("fClingParameters"))[1], 2)) + " $\pm$ " + str(round(list(fsim.member("fFormula").member("fClingParameters"))[2], 2)) + " MeV"
#      49 plt.xlabel("Energy deposition of hit $\\times$ cos($\\theta$) [MeV]", fontsize = 18)
#
# AttributeError: 'NoneType' object has no attribute 'member'

# %%
#This code aims to import, into python, the landau-fitted histogram produced by LRMSFullEdep.C / TheChoseOne.C and similar codes
import uproot
import numpy as np
import matplotlib.pyplot as plt

hhist = uproot.open("p4hstrip.root") #Saved root histogram pre-fitted in the root macro
h = uproot.open("p4hstrip.root:h0_l0r5m3s17") #Pull the fit function separately
simhist = uproot.open("h212strip.root")
sim = uproot.open("h212strip.root:h0_l0r5m3s17") #Pull the fit function separately

hist_mcm = hhist["h0_l0r5m3s17"] #This variable involves the actual histogram, not the fit
edges = hist_mcm.axis().edges()  # Using h1's binning
values1 = hist_mcm.values()

hist_sim = simhist["h0_l0r5m3s17"] #This variable involves the actual histogram, not the fit
simedges = hist_sim.axis().edges()  # Using h1's binning
values2 = hist_sim.values()

f = h.member("fFunctions")[0]
fsim = sim.member("fFunctions")[0]

#Need to save the x and y values of the fit
l = list(f.member("fSave"))                                 
x_values = np.linspace(l[-2], l[-1], len(l[:-2]))
y_values = l[:-2]

#Need to save the x and y values of the fit
lsim = list(fsim.member("fSave"))
xsim_values = np.linspace(lsim[-2], lsim[-1], len(lsim[:-2]))
ysim_values = lsim[:-2]

# Create the plot
plt.figure(figsize=(8, 8))

plt.hist(edges[:-1], bins=edges, histtype='step', weights=values1, alpha=0.5, label=hist_mcm.name,color='mediumblue')
plt.plot(x_values, y_values, color="mediumblue") #Plot the fit
plt.hist(simedges[:-1], bins=simedges, histtype='step', weights=values2, alpha=0.5, label=hist_sim.name,color='tomato')
plt.plot(xsim_values, ysim_values, color="tomato",linestyle='--') #Plot the fit

plt.xlabel("Energy Deposition of Hit $\\times$ Cos($\\theta$) [MeV]", fontsize = 18)
plt.ylabel("Number of Hits on Track", fontsize = 18)
plt.tick_params(axis='both', labelsize=12)
plt.title('')
#plt.grid(True, alpha=0.3) #Make grid with opacity 0.3

mcmmpvvals = str(round(list(f.member("fFormula").member("fClingParameters"))[1], 2)) + " $\pm$ " + str(round(list(f.member("fFormula").member("fClingParameters"))[2], 2)) + " MeV"
simmpvvals = str(round(list(fsim.member("fFormula").member("fClingParameters"))[1], 2)) + " $\pm$ " + str(round(list(fsim.member("fFormula").member("fClingParameters"))[2], 2)) + " MeV"

plt.xlabel("Energy deposition of hit $\\times$ cos($\\theta$) [MeV]", fontsize = 18)
plt.ylabel("Number of hits on track", fontsize = 18)
plt.title('')

plt.xlim(0.3, 3.5)
plt.ylim(0.1, 200)
plt.yscale('log')
plt.minorticks_off()

#Axis formatting
ax = plt.gca()
ax.tick_params(axis='both', which='major', direction='in', labelsize=16, width=1.5, length=6, top=True, right=True, labeltop=False, labelright=False)

plt.legend(['McMurdo Data: Run 9125', 'MPV: ' + mcmmpvvals, 'Muon MC', 'MPV: ' + simmpvvals], fontsize = 18,frameon=False)

plt.xlim(0.3, 3.5)
plt.ylim(0.1, 200)
plt.tight_layout()
plt.savefig('MCM_and_Sim_MPV.png')
plt.show()

# %%
#This code aims to import, into python, the landau-fitted histogram produced by LRMSFullEdep.C / TheChoseOne.C and similar codes
import uproot
import numpy as np
import matplotlib.pyplot as plt

hhist = uproot.open("p4hdet.root") #Saved root histogram pre-fitted in the root macro
h = uproot.open("p4det.root:h0_l0r5m3d4") #Pull the fit function separately
simhist = uproot.open("h212det.root")
sim = uproot.open("h212det.root:h0_l0r5m3d4") #Pull the fit function separately

hist_mcm = hhist["h0_l0r5m3d4"] #This variable involves the actual histogram, not the fit
edges = hist_mcm.axis().edges()  # Using h1's binning
values1 = hist_mcm.values()

hist_sim = simhist["h0_l0r5m3d4"] #This variable involves the actual histogram, not the fit
simedges = hist_sim.axis().edges()  # Using h1's binning
values2 = hist_sim.values()

f = h.member("fFunctions")[0]
fsim = sim.member("fFunctions")[0]

#Need to save the x and y values of the fit
l = list(f.member("fSave"))                                 
x_values = np.linspace(l[-2], l[-1], len(l[:-2]))
y_values = l[:-2]

#Need to save the x and y values of the fit
lsim = list(fsim.member("fSave"))
xsim_values = np.linspace(lsim[-2], lsim[-1], len(lsim[:-2]))
ysim_values = lsim[:-2]

# Create the plot
plt.figure(figsize=(8, 8))

plt.hist(edges[:-1], bins=edges, histtype='step', hatch='////////', weights=values1, alpha=0.65, label=hist_mcm.name,color='mediumblue')
plt.plot(x_values, y_values, color="mediumblue", linewidth = 3) #Plot the fit
plt.hist(simedges[:-1], bins=simedges, histtype='step', hatch = '\\\\\\\\\\\\\\', weights=values2, alpha=0.55, label=hist_sim.name,color='tomato')
plt.plot(xsim_values, ysim_values, color="tomato",linestyle='--',linewidth = 3) #Plot the fit

plt.xlabel("Energy Deposition of Hit $\\times$ Cos($\\theta$) [MeV]", fontsize = 18)
plt.ylabel("Number of Hits on Track", fontsize = 18)
plt.tick_params(axis='both', labelsize=12)
plt.title('')
#plt.grid(True, alpha=0.3) #Make grid with opacity 0.3

mcmmpvvals = str(round(list(f.member("fFormula").member("fClingParameters"))[1], 2)) + " $\pm$ " + str(round(list(f.member("fFormula").member("fClingParameters"))[2], 2)) + " MeV"
simmpvvals = str(round(list(fsim.member("fFormula").member("fClingParameters"))[1], 2)) + " $\pm$ " + str(round(list(fsim.member("fFormula").member("fClingParameters"))[2], 2)) + " MeV"

plt.xlabel("Energy deposition of hit $\\times$ cos($\\theta$) [MeV]", fontsize = 18)
plt.ylabel("Number of hits on track", fontsize = 18)
plt.title('')

plt.xlim(0.3, 3.5)
plt.ylim(0.1, 200)
plt.yscale('log')
plt.minorticks_off()

#Axis formatting
ax = plt.gca()
ax.tick_params(axis='both', which='major', direction='in', labelsize=16, width=1.5, length=6, top=True, right=True, labeltop=False, labelright=False)

plt.legend(['McMurdo Data: 12-13-2024', 'MPV: ' + mcmmpvvals, 'Muon MC', 'MPV: ' + simmpvvals], fontsize = 18,frameon=False)


# adding 'PRELIMINARY' watermark right below the legend (currently in top left corner)
ax.text(0.8, 0.7, 'PRELIMINARY', verticalalignment='bottom', horizontalalignment='right', transform=ax.transAxes, color='gray', fontsize=16)

plt.xlim(0.3, 3.5)
plt.ylim(0.1, 200)
plt.tight_layout()
plt.savefig('MCM_and_Sim_MPV.png')
plt.show()


plt.figure(figsize=(8, 8))

plt.hist(edges[:-1], bins=edges,histtype='step', hatch='////////', weights=values1, alpha=0.5, label=hist_mcm.name,color='mediumblue')
plt.plot(x_values, y_values, color="mediumblue",linewidth = 3) #Plot the fit

plt.xlabel("Energy deposition of hit $\\times$ cos($\\theta$) [MeV]", fontsize = 18)
plt.ylabel("Number of hits on track", fontsize = 18)
plt.title('')
plt.xlim(0.3, 3.5)
plt.ylim(0.1, 200)
plt.yscale('log')
plt.minorticks_off()

#Axis formatting
ax = plt.gca()
ax.tick_params(axis='both', which='major', direction='in', labelsize=16, width=1.5, length=6, top=True, right=True, labeltop=False, labelright=False)


# adding 'PRELIMINARY' watermark right below the legend (currently in top left corner)
ax.text(0.8, 0.8, 'PRELIMINARY', verticalalignment='bottom', horizontalalignment='right', transform=ax.transAxes, color='gray', fontsize=16)

plt.legend(['McMurdo Data: 12-13-2024', 'MPV: ' + mcmmpvvals], fontsize = 18,frameon=False)
plt.tight_layout()
plt.savefig('MCM_MPV.png')
plt.show()
