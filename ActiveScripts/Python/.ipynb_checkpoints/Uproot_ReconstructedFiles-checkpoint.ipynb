# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt

#;____; I couldn't figure it out and should do a different thing now!!!
#How to open events and Event->GetPrimary() etc... and everything in uproot?

# %%
filename = "/home/kelsey/simulations/simdat/flight/251221/H3D/starlink251221_0003_FindHough3D_rec.root"
file = uproot.open("/home/kelsey/simulations/simdat/flight/251221/H3D/starlink251221_0003_FindHough3D_rec.root")

# %%
with uproot.open(filename) as rfile:
    print(rfile.keys())
    print(rfile.classnames())

print(type(file))
print(type(file.keys()) )
print(file.keys() )
print(file['TreeRec;1'] )
print(type(file['TreeRec;1']) )


print(file['TreeRec;1'].keys() )

print(file['TreeRec;1']['Rec/primaryBeta_'].keys() )

print(file['TreeRec;1']['Rec/primaryBeta_']['primaryBeta_.first'] )

#print(file['TDirectory'] )
# Out:
# ['GGeometry;1', 'TreeGReco;2', 'TreeGReco;1', 'TreeRec;1', 'GOptions;1', 'GOptions/CraneBaseProcessing;1']
# {'GGeometry;1': 'TGeoManager', 'TreeGReco;2': 'TTree', 'TreeGReco;1': 'TTree', 'TreeRec;1': 'TTree', 'GOptions;1': 'TDirectory', 'GOptions/CraneBaseProcessing;1': 'vector<array<string,3> >'}
# <class 'uproot.reading.ReadOnlyDirectory'>
# <class 'list'>
# ['GGeometry;1', 'TreeGReco;2', 'TreeGReco;1', 'TreeRec;1', 'GOptions;1', 'GOptions/CraneBaseProcessing;1']
# <TTree 'TreeRec' (1 branches) at 0x7ae2d28c8f40>
# <class 'uproot.models.TTree.Model_TTree_v20'>
# ...

# %%
#file2 = uproot.open("/home/kelsey/simulations/simdat/flight/251221/H3D/starlink251221_0003_FindHough3D_rec.root:TreeRec;1")

for array in uproot.iterate("/home/kelsey/simulations/simdat/flight/251221/H3D/starlink251221_0003_FindHough3D_rec.root:TreeRec;1", ['Rec/primaryBeta_']['primaryBeta_.first'], step_size=100):
    print('hey')
# Out:
# <>:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# /tmp/ipykernel_81737/3232761052.py:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   for array in uproot.iterate("/home/kelsey/simulations/simdat/flight/251221/H3D/starlink251221_0003_FindHough3D_rec.root:TreeRec;1", ['Rec/primaryBeta_']['primaryBeta_.first'], step_size=100):
# /tmp/ipykernel_81737/3232761052.py:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   for array in uproot.iterate("/home/kelsey/simulations/simdat/flight/251221/H3D/starlink251221_0003_FindHough3D_rec.root:TreeRec;1", ['Rec/primaryBeta_']['primaryBeta_.first'], step_size=100):
# /tmp/ipykernel_81737/3232761052.py:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# ...
