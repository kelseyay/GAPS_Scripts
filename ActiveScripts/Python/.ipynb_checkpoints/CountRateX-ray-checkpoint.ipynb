# %%
import matplotlib.pyplot as plt
import pylab
import os

# %%
prename = r"/home/kelsey/simulations/terra/CU\ Energy\ Resolution/1-22-2026\ X-rays\ on\ Sh0136/Rise\ Time\ Varying/"
name = r"test" + ".txt"
file_path = os.path.join(prename)
txtname = os.path.join(prename,name)
print(txtname)
if os.path.exists(file_path):
    print(f"Path exists: {file_path}")
    pltfile = open(txtname, "r")
    nlines = len(open(name).readlines(  ))
# Out:
# /home/kelsey/simulations/terra/CU\ Energy\ Resolution/1-22-2026\ X-rays\ on\ Sh0136/Rise\ Time\ Varying/test.txt
